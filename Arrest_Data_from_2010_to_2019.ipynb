# %%
import pandas as pd

import numpy as np

# %%
arrest_data = pd.read_csv("Arrest_Data_from_2010_to_Present.csv")

arrest_data.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  05/03/2019  1700.0       18  Southeast                1802   23
# 1    5614161  04/29/2019  1040.0        8    West LA                 842   41
# 2    5615197  04/30/2019   615.0        6  Hollywood                 663   27
# 3    5615701  04/30/2019  1100.0        9   Van Nuys                 901    2
# 4    5615929  04/30/2019  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# 0                M    653.22 PC                NaN
# 1                F        211PC            ROBBERY
# 2                F        459PC           BURGLARY
# 3                D    300(B)WIC                NaN
# 4                F  245(A)(2)PC      ADW W/FIREARM
#
#                                     Address                     Cross Street  \
# 0                                      91ST                         FIGUEROA
# 1  11600    WILSHIRE                     BL                              NaN
# 2                                   LA BREA                        LEXINGTON
# 3                                    RAYMER  SEPULVEDA                    BL
# 4           8TH                          ST                          VERMONT
#
#                Location
# 0  (33.9543, -118.2827)
# 1  (34.0508, -118.4592)
# 2  (34.0907, -118.3384)
# 3  (34.2149, -118.4674)
# 4  (34.0578, -118.2916)

# %%
arrest_data.shape
# Out:
# (1310127, 17)

# %%
arrest_data.columns
# Out:
# Index(['Report ID', 'Arrest Date', 'Time', 'Area ID', 'Area Name',
#        'Reporting District', 'Age', 'Sex Code', 'Descent Code',
#        'Charge Group Code', 'Charge Group Description', 'Arrest Type Code',
#        'Charge', 'Charge Description', 'Address', 'Cross Street', 'Location'],
#       dtype='object')

# %%
arrest_data['Arrest Date'].min()
# Out:
# '01/01/2010'

# %%
from datetime import datetime

# %%
arrest_data['Arrest Date'] = pd.to_datetime(arrest_data['Arrest Date'])

# %%
start_date = '01/01/2018'
end_date = '12/31/2018'

# %%
mask = (arrest_data['Arrest Date'] > '01/01/2018') & (arrest_data['Arrest Date'] <= '12/31/2018')

# %%
mask.tail()
# Out:
# 1310122    False
# 1310123    False
# 1310124    False
# 1310125    False
# 1310126    False
# Name: Arrest Date, dtype: bool

# %%
booking2018_data = arrest_data.loc[mask]

# %%
booking2018_data.head(3)
# Out:
#      Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 156    5213460  2018-01-24  1930.0        6  Hollywood                 668
# 157    5257944  2018-03-15   310.0        7   Wilshire                 743
# 158    5328813  2018-06-01  1800.0        3  Southwest                 356
#
#      Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 156   29        M            H               10.0       Fraud/Embezzlement
# 157   33        F            O                1.0                 Homicide
# 158   44        F            B               16.0       Narcotic Drug Laws
#
#     Arrest Type Code      Charge                         Charge Description  \
# 156                F  530.5(A)PC                  GET CREDIT/ETC OTHER'S ID
# 157                F  191.5(B)PC  VEH MANSLAUGHTR/OPER VESSEL DUI & DUR FEL
# 158                F  11379(A)HS        TRANSPORT/SELL CONTROLLED SUBSTANCE
#
#                                      Address Cross Street  \
# 156                               ST ANDREWS     FOUNTAIN
# 157                                  OLYMPIC     MASSELIN
# 158  1600 W  36TH                         PL          NaN
#
#                  Location
# 156  (34.0949, -118.3109)
# 157  (34.0574, -118.3547)
# 158  (34.0219, -118.3061)

# %%
booking2018_data['Report ID'].count()
# Out:
# 104040

# %%
booking2018_data.tail(3)
# Out:
#          Report ID Arrest Date    Time  Area ID   Area Name  \
# 1290588    5509344  2018-12-31   720.0       11   Northeast
# 1290595    5509947  2018-12-31  2320.0        4  Hollenbeck
# 1290614    5509405  2018-12-31  1200.0       19     Mission
#
#          Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 1290588                1133   25        M            H                6.0
# 1290595                 408   23        M            H               16.0
# 1290614                1921   28        F            H                7.0
#
#         Charge Group Description Arrest Type Code      Charge  \
# 1290588                  Larceny                M     490.2PC
# 1290595       Narcotic Drug Laws                F     11378HS
# 1290614            Vehicle Theft                F  10851(A)VC
#
#                                Charge Description  \
# 1290588                               PETTY THEFT
# 1290595  POSSESSION CONTROLLED SUBSTANCE FOR SALE
# 1290614          TAKE VEHICLE W/O OWNER'S CONSENT
#
#                                           Address Cross Street  \
# 1290588   3100    GLENDALE                     BL          NaN
# 1290595                                HUNTINGTON     ROSEMEAD
# 1290614  15100    POLK                         ST          NaN
#
#                      Location
# 1290588  (34.1119, -118.2529)
# 1290595   (34.0872, -118.176)
# 1290614  (34.3009, -118.4696)

# %%
small = ['Vehicle Theft','Robbery','Burglary', 'Receive Stolen Property']

small_data=booking2018_data[booking2018_data['Charge Group Description'].isin(small)]

small_data.shape
# Out:
# (8428, 17)

# %%
small_data.tail(3)
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 1290453    5509149  2018-12-30  2230.0       12  77th Street
# 1290486    5509524  2018-12-31  1300.0       11    Northeast
# 1290614    5509405  2018-12-31  1200.0       19      Mission
#
#          Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 1290453                1256   28        M            H                7.0
# 1290486                1128   21        M            B                3.0
# 1290614                1921   28        F            H                7.0
#
#         Charge Group Description Arrest Type Code      Charge  \
# 1290453            Vehicle Theft                F  10851(A)VC
# 1290486                  Robbery                F       211PC
# 1290614            Vehicle Theft                F  10851(A)VC
#
#                        Charge Description  \
# 1290453  TAKE VEHICLE W/O OWNER'S CONSENT
# 1290486                           ROBBERY
# 1290614  TAKE VEHICLE W/O OWNER'S CONSENT
#
#                                           Address  \
# 1290453           FLORENCE                     AV
# 1290486           YORK                         BL
# 1290614  15100    POLK                         ST
#
#                             Cross Street              Location
# 1290453  BROADWAY                     ST  (33.9747, -118.2783)
# 1290486  FIGUEROA                     BL  (34.1152, -118.1837)
# 1290614                              NaN  (34.3009, -118.4696)

# %%
small_data['Age'].sort_values
# Out:
# <bound method Series.sort_values of 167        43
# 172        32
# 173        26
# 175        32
# 176        27
# 177        20
# 178        25
# 184        18
# 185        38
# 193        27
# 194        21
# 197        39
# 198        26
# 2586       26
# 2590       20
# 2616       31
# 2624       38
# 2625       25
# 2627       34
# 2628       32
# 2658       38
# 4733       21
# 4735       24
# 4737       59
# 4761       18
# 4762       19
# 4769       37
# 6754       33
# 6760       31
# 6774       19
#            ..
# 1289157    17
# 1289163    31
# 1289166    26
# 1289171    32
# 1289174    38
# 1289175    18
# 1289179    16
# 1289184    25
# 1289189    19
# 1289228    43
# 1289232    23
# 1289236    39
# 1289400    24
# 1289405    28
# 1289537    38
# 1289830    27
# 1289927    23
# 1289945    33
# 1289953    58
# 1290025    28
# 1290062    23
# 1290107    36
# 1290132    20
# 1290147    31
# 1290201    22
# 1290288    39
# 1290333    18
# 1290453    28
# 1290486    21
# 1290614    28
# Name: Age, Length: 8428, dtype: int64>

# %%
np.quantile(small_data['Age'], .95)
# Out:
# 52.0

# %%
mask10_18 = (arrest_data['Arrest Date'] >= '01/01/2010') & (arrest_data['Arrest Date'] <= '12/31/2018')

# %%
mask10_18.head(3)
# Out:
# 0    False
# 1    False
# 2    False
# Name: Arrest Date, dtype: bool

# %%
booking10_18_data = arrest_data.loc[mask10_18]

# %%
booking10_18_data.tail(3)
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 1310112    9919836  2010-01-19   800.0        3    Southwest
# 1310113    8526595  2013-10-15  1645.0       15  N Hollywood
# 1310114    9791154  2010-01-19  2200.0        8      West LA
#
#          Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 1310112                 361   37        F            O                6.0
# 1310113                1505   22        M            H               24.0
# 1310114                 857   37        F            O               13.0
#
#                Charge Group Description Arrest Type Code       Charge  \
# 1310112                         Larceny                F     487(A)PC
# 1310113  Miscellaneous Other Violations                F  594(B)(1)PC
# 1310114             Prostitution/Allied                M     647(B)PC
#
#                            Charge Description  \
# 1310112     GRAND THEFT MONEY/PROPERTY > $400
# 1310113  VANDALISM W/LOSS VALUED EQ OR > $400
# 1310114                          PROSTITUTION
#
#                                          Address Cross Street  \
# 1310112  3900    GIBRALTAR                    AV          NaN
# 1310113  7400    CAMELLIA                     AV          NaN
# 1310114  1200 S  BEVERLY                      DR          NaN
#
#                      Location
# 1310112  (34.0161, -118.3547)
# 1310113  (34.2061, -118.3823)
# 1310114  (34.0546, -118.3953)

# %%
booking10_18_data.shape
# Out:
# (1231627, 17)

# %%
arrest_data['Arrest Type Code'].head()
# Out:
# 0    M
# 1    F
# 2    F
# 3    D
# 4    F
# Name: Arrest Type Code, dtype: object

# %%
start_date = '01/01/2010'
end_date = '12/31/2010'

# %%
mask_10 = (arrest_data['Arrest Date'] >= '01/01/2010') & (arrest_data['Arrest Date'] <= '12/31/2010')

# %%
mask_10.head(3)
# Out:
# 0    False
# 1    False
# 2    False
# Name: Arrest Date, dtype: bool

# %%
arrest_data_10 = arrest_data.loc[mask_10].head(3)

# %%
arrest_data_10.tail(10)
# Out:
#        Report ID Arrest Date    Time  Area ID    Area Name  \
# 6722     2593624  2010-12-31  1915.0        7     Wilshire
# 32877    2281627  2010-03-31  1730.0       15  N Hollywood
# 36970    2292485  2010-04-09  1700.0       19      Mission
#
#        Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 6722                  776   41        M            B               24.0
# 32877                1525   37        M            W                6.0
# 36970                1999   43        M            H               16.0
#
#              Charge Group Description Arrest Type Code       Charge  \
# 6722   Miscellaneous Other Violations                M  166(A)(4)PC
# 32877                         Larceny                M     484(A)PC
# 36970              Narcotic Drug Laws                F   11350(A)HS
#
#                              Charge Description  \
# 6722    CONTEMPT OF COURT - DISOBEY COURT ORDER
# 32877                   GRAND THEFT (OVER $400)
# 36970  POSSESSION NARCOTIC CONTROLLED SUBSTANCE
#
#                                        Address Cross Street  \
# 6722   4500 W  WASHINGTON                   BL          NaN
# 32877  6100    LAUREL CANYON                BL          NaN
# 36970                                  WOODMAN      SATICOY
#
#                    Location
# 6722   (34.0441, -118.3378)
# 32877  (34.1815, -118.3965)
# 36970  (34.2095, -118.4309)

# %%
arrest_data_10.head(100)
# Out:
#        Report ID Arrest Date    Time  Area ID    Area Name  \
# 6722     2593624  2010-12-31  1915.0        7     Wilshire
# 32877    2281627  2010-03-31  1730.0       15  N Hollywood
# 36970    2292485  2010-04-09  1700.0       19      Mission
#
#        Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 6722                  776   41        M            B               24.0
# 32877                1525   37        M            W                6.0
# 36970                1999   43        M            H               16.0
#
#              Charge Group Description Arrest Type Code       Charge  \
# 6722   Miscellaneous Other Violations                M  166(A)(4)PC
# 32877                         Larceny                M     484(A)PC
# 36970              Narcotic Drug Laws                F   11350(A)HS
#
#                              Charge Description  \
# 6722    CONTEMPT OF COURT - DISOBEY COURT ORDER
# 32877                   GRAND THEFT (OVER $400)
# 36970  POSSESSION NARCOTIC CONTROLLED SUBSTANCE
#
#                                        Address Cross Street  \
# 6722   4500 W  WASHINGTON                   BL          NaN
# 32877  6100    LAUREL CANYON                BL          NaN
# 36970                                  WOODMAN      SATICOY
#
#                    Location
# 6722   (34.0441, -118.3378)
# 32877  (34.1815, -118.3965)
# 36970  (34.2095, -118.4309)

# %%
import re
    
fel = arrest_data_10['Arrest Type Code'].str.contains('F')

felo_10 = arrest_data_10[fel]

felo_10
# Out:
#        Report ID Arrest Date    Time  Area ID Area Name  Reporting District  \
# 36970    2292485  2010-04-09  1700.0       19   Mission                1999
#
#        Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 36970   43        M            H               16.0       Narcotic Drug Laws
#
#       Arrest Type Code      Charge                        Charge Description  \
# 36970                F  11350(A)HS  POSSESSION NARCOTIC CONTROLLED SUBSTANCE
#
#        Address Cross Street              Location
# 36970  WOODMAN      SATICOY  (34.2095, -118.4309)

# %%
felo_10
# Out:
#        Report ID Arrest Date    Time  Area ID Area Name  Reporting District  \
# 36970    2292485  2010-04-09  1700.0       19   Mission                1999
#
#        Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 36970   43        M            H               16.0       Narcotic Drug Laws
#
#       Arrest Type Code      Charge                        Charge Description  \
# 36970                F  11350(A)HS  POSSESSION NARCOTIC CONTROLLED SUBSTANCE
#
#        Address Cross Street              Location
# 36970  WOODMAN      SATICOY  (34.2095, -118.4309)

# %%
start_date = '01/01/2018'
end_date = '12/31/2018'

mask_18 = (arrest_data['Arrest Date'] >= '01/01/2018') & (arrest_data['Arrest Date'] <= '12/31/2018')

# %%
arrest_data_18 = arrest_data.loc[mask_18]

# %%
arrest_data_18.tail(3)
# Out:
#          Report ID Arrest Date    Time  Area ID   Area Name  \
# 1290588    5509344  2018-12-31   720.0       11   Northeast
# 1290595    5509947  2018-12-31  2320.0        4  Hollenbeck
# 1290614    5509405  2018-12-31  1200.0       19     Mission
#
#          Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 1290588                1133   25        M            H                6.0
# 1290595                 408   23        M            H               16.0
# 1290614                1921   28        F            H                7.0
#
#         Charge Group Description Arrest Type Code      Charge  \
# 1290588                  Larceny                M     490.2PC
# 1290595       Narcotic Drug Laws                F     11378HS
# 1290614            Vehicle Theft                F  10851(A)VC
#
#                                Charge Description  \
# 1290588                               PETTY THEFT
# 1290595  POSSESSION CONTROLLED SUBSTANCE FOR SALE
# 1290614          TAKE VEHICLE W/O OWNER'S CONSENT
#
#                                           Address Cross Street  \
# 1290588   3100    GLENDALE                     BL          NaN
# 1290595                                HUNTINGTON     ROSEMEAD
# 1290614  15100    POLK                         ST          NaN
#
#                      Location
# 1290588  (34.1119, -118.2529)
# 1290595   (34.0872, -118.176)
# 1290614  (34.3009, -118.4696)

# %%
feell =  arrest_data_18['Arrest Type Code'].str.contains('F')

felo_18 = arrest_data_18[feell]

# %%
felo_18.tail(3)
# Out:
#          Report ID Arrest Date    Time  Area ID   Area Name  \
# 1290583    5509487  2018-12-31  1545.0        1     Central
# 1290595    5509947  2018-12-31  2320.0        4  Hollenbeck
# 1290614    5509405  2018-12-31  1200.0       19     Mission
#
#          Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 1290583                 155   55        M            B                8.0
# 1290595                 408   23        M            H               16.0
# 1290614                1921   28        F            H                7.0
#
#         Charge Group Description Arrest Type Code      Charge  \
# 1290583           Other Assaults                F    422(A)PC
# 1290595       Narcotic Drug Laws                F     11378HS
# 1290614            Vehicle Theft                F  10851(A)VC
#
#                                Charge Description  \
# 1290583                    TERRORIZE CAUSING FEAR
# 1290595  POSSESSION CONTROLLED SUBSTANCE FOR SALE
# 1290614          TAKE VEHICLE W/O OWNER'S CONSENT
#
#                                           Address Cross Street  \
# 1290583           5TH                          ST        MAPLE
# 1290595                                HUNTINGTON     ROSEMEAD
# 1290614  15100    POLK                         ST          NaN
#
#                      Location
# 1290583  (34.0454, -118.2466)
# 1290595   (34.0872, -118.176)
# 1290614  (34.3009, -118.4696)

# %%
felo_18.shape
# Out:
# (34948, 17)

# %%
felo_18.shape
# Out:
# (34948, 17)

# %%
# equation of the line of  best fit : Y = mX + b

# the line of best fits passes through points K(2010, 1), L(2018, 34948),  m = 34948-1/2018-2010 <==> m = 34947/8 = 4368.375

# if X = 2010, Y = 1, B = Y - mX  <==> B = 1 - 4368.37 x 2010 <==> b = - 8,780,432.75

# Equation of the line of best fit Y = 4368.375X - 8,780,432.75

# extrapolation: 

# if X = 2019, Y= 4368.375 X 2019 - 8,780,432.75 = 39,316.375

# So if X = 2019, Y = 39,316 representing the point M(2019, 39,316)

# %%
arrest_data_18['Area Name'].value_counts(dropna=False).head()
# Out:
# Central        10951
# Hollywood       9715
# Rampart         7345
# Pacific         6778
# 77th Street     6259
# Name: Area Name, dtype: int64

# %%
arrest_data_18['Area Name'].value_counts(dropna=False).tail()
# Out:
# Devonshire    3146
# Topanga       3094
# Foothill      3006
# West LA       2687
# Wilshire      2467
# Name: Area Name, dtype: int64

# %%
emil_2018 = arrest_data_18[~arrest_data_18['Charge Group Description'].isin(["Pre-Delinquency", "Non-Criminal Detention"])]

# %%
emil_2018.head(100)
# Out:
#       Report ID Arrest Date    Time  Area ID    Area Name  Reporting District  \
# 156     5213460  2018-01-24  1930.0        6    Hollywood                 668
# 157     5257944  2018-03-15   310.0        7     Wilshire                 743
# 158     5328813  2018-06-01  1800.0        3    Southwest                 356
# 159     5336331  2018-06-10   200.0       13       Newton                1364
# 160     5360731  2018-07-07  2330.0       18    Southeast                1832
# 161     5404690  2018-08-25  1850.0       18    Southeast                1832
# 162     5406551  2018-08-27  2300.0       18    Southeast                1842
# 165     5419122  2018-09-10  1620.0       12  77th Street                1251
# 166     5430543  2018-09-23  1830.0       13       Newton                1321
# 167     5449454  2018-10-15  2330.0        1      Central                 157
# 172     5449463  2018-10-15  2330.0        1      Central                 154
# 173     5452727  2018-10-19  1935.0        1      Central                 100
# 174     5456681  2018-10-25    30.0        6    Hollywood                 643
# 175     5460361  2018-10-29  1550.0       12  77th Street                1208
# 176     5464308  2018-11-03   350.0        1      Central                 159
# 177     5471809  2018-11-12  2315.0        1      Central                 138
# 178     5476070  2018-11-18   300.0        1      Central                 185
# 179     5476213  2018-11-18  1000.0       12  77th Street                1204
# 180     5477205  2018-11-19  1600.0       13       Newton                1347
# 181     5477482  2018-11-20   705.0        1      Central                 134
# 182     5478144  2018-11-21   811.0       12  77th Street                1208
# 183     5478957  2018-11-22   940.0        8      West LA                 827
# 184     5482231  2018-11-26  2320.0       20      Olympic                2019
# 185     5485057  2018-11-30   840.0        1      Central                 155
# 186     5485873  2018-12-01  1350.0       20      Olympic                2076
# 187     5488322  2018-12-04  1530.0       20      Olympic                2029
# 188     5492070  2018-12-09  1847.0       20      Olympic                2039
# 189     5493854  2018-12-11  2020.0       13       Newton                1363
# 190     5497380  2018-12-15  2120.0        7     Wilshire                 706
# 191     5497391  2018-12-15  2120.0        7     Wilshire                 706
# ...         ...         ...     ...      ...          ...                 ...
# 2622    5477124  2018-11-19  1245.0        3    Southwest                 336
# 2623    5482197  2018-11-26  2215.0       16     Foothill                1681
# 2624    5482230  2018-11-27    15.0        5       Harbor                 529
# 2625    5482424  2018-11-27   720.0       20      Olympic                2044
# 2626    5482715  2018-11-27  1520.0       20      Olympic                2029
# 2627    5489624  2018-12-06   815.0        5       Harbor                 531
# 2628    5493924  2018-12-12   315.0        2      Rampart                 248
# 2629    5484286  2018-11-29  1220.0       18    Southeast                1822
# 2630    5464231  2018-11-02  1830.0        2      Rampart                 257
# 2631    5424104  2018-09-15  2300.0       18    Southeast                1871
# 2632    5495647  2018-12-13  2315.0        2      Rampart                 233
# 2633    5500179  2018-12-19   930.0        2      Rampart                 249
# 2634    5506393  2018-12-27  1630.0       16     Foothill                1682
# 2635    5507245  2018-12-28  1540.0       12  77th Street                1259
# 2636    5509169  2018-12-30  2345.0       18    Southeast                1802
# 2637    5509684  2018-12-31  2310.0        3    Southwest                 397
# 2658    5500596  2018-12-20    15.0       18    Southeast                1863
# 4733    5195827  2018-01-04  1935.0       13       Newton                1331
# 4734    5218232  2018-01-29  1955.0        6    Hollywood                 646
# 4735    5218250  2018-01-29  1955.0        6    Hollywood                 646
# 4736    5219480  2018-01-31   225.0       15  N Hollywood                1503
# 4737    5254796  2018-03-11  1230.0        3    Southwest                 307
# 4738    5267062  2018-03-26   345.0       10  West Valley                1007
# 4739    5270090  2018-03-29   931.0        8      West LA                 836
# 4740    5274987  2018-04-04   115.0        6    Hollywood                 645
# 4743    5349417  2018-06-24  2130.0        3    Southwest                 362
# 4744    5368563  2018-07-16  1300.0        3    Southwest                 361
# 4745    5382082  2018-07-31  1700.0       12  77th Street                1241
# 4746    5382151  2018-07-31  1700.0       12  77th Street                1241
# 4747    5382764  2018-08-01  1200.0       17   Devonshire                1783
#
#       Age Sex Code Descent Code  Charge Group Code  \
# 156    29        M            H               10.0
# 157    33        F            O                1.0
# 158    44        F            B               16.0
# 159    23        M            H               12.0
# 160    32        M            B               12.0
# 161    39        M            B               12.0
# 162    31        M            B               12.0
# 165    57        M            B                8.0
# 166    25        M            H               24.0
# 167    43        M            H                7.0
# 172    32        M            H                7.0
# 173    26        M            B                7.0
# 174    48        M            H                4.0
# 175    32        F            H                7.0
# 176    27        M            W                7.0
# 177    20        M            H                7.0
# 178    25        M            B                7.0
# 179    42        M            H                8.0
# 180    19        M            H               12.0
# 181    35        F            W               24.0
# 182    47        M            B                4.0
# 183    21        F            W               22.0
# 184    18        M            H                3.0
# 185    38        M            H                5.0
# 186    37        M            B                8.0
# 187    26        M            H               24.0
# 188    33        M            W               15.0
# 189    39        F            H               12.0
# 190    36        M            H               12.0
# 191    27        M            H               12.0
# ...   ...      ...          ...                ...
# 2622   56        M            B                4.0
# 2623   27        M            H               12.0
# 2624   38        F            W                5.0
# 2625   25        F            H                7.0
# 2626   22        F            H                6.0
# 2627   34        F            B                3.0
# 2628   32        M            B                5.0
# 2629   57        M            B                4.0
# 2630   31        M            H                4.0
# 2631   36        M            H               23.0
# 2632   16        M            H               24.0
# 2633   54        M            W                4.0
# 2634   34        M            W                4.0
# 2635   36        F            B                8.0
# 2636   38        M            B                9.0
# 2637   19        F            H                8.0
# 2658   38        M            B                7.0
# 4733   21        M            H                3.0
# 4734   28        M            B               24.0
# 4735   24        M            B               11.0
# 4736   23        M            H                4.0
# 4737   59        F            B                3.0
# 4738   24        M            H               22.0
# 4739   53        M            W                6.0
# 4740   24        M            B               24.0
# 4743   27        F            B                8.0
# 4744   23        M            B                4.0
# 4745   24        F            H                8.0
# 4746   34        M            H                8.0
# 4747   21        M            H               24.0
#
#             Charge Group Description Arrest Type Code       Charge  \
# 156               Fraud/Embezzlement                F   530.5(A)PC
# 157                         Homicide                F   191.5(B)PC
# 158               Narcotic Drug Laws                F   11379(A)HS
# 159              Weapon (carry/poss)                F  25400(A)2PC
# 160              Weapon (carry/poss)                F  29800(A)1PC
# 161              Weapon (carry/poss)                F  29800(A)1PC
# 162              Weapon (carry/poss)                F  25400(A)1PC
# 165                   Other Assaults                F     422(A)PC
# 166   Miscellaneous Other Violations                F  594(B)(1)PC
# 167                    Vehicle Theft                F   10851(A)VC
# 172                    Vehicle Theft                F   10851(A)VC
# 173                    Vehicle Theft                F   10851(A)VC
# 174               Aggravated Assault                F  245(A)(1)PC
# 175                    Vehicle Theft                F   10851(A)VC
# 176                    Vehicle Theft                F   10851(A)VC
# 177                    Vehicle Theft                F   10851(E)VC
# 178                    Vehicle Theft                F   10851(A)VC
# 179                   Other Assaults                F     422(A)PC
# 180              Weapon (carry/poss)                F   25850(A)PC
# 181   Miscellaneous Other Violations                F  594(A)(1)PC
# 182               Aggravated Assault                F  245(A)(1)PC
# 183          Driving Under Influence                F   23153(A)VC
# 184                          Robbery                F        211PC
# 185                         Burglary                F        459PC
# 186                   Other Assaults                M     243(B)PC
# 187   Miscellaneous Other Violations                F  594(A)(2)PC
# 188             Against Family/Child                M   273.6(A)PC
# 189              Weapon (carry/poss)                F  25400(A)1PC
# 190              Weapon (carry/poss)                F  29800(A)1PC
# 191              Weapon (carry/poss)                M   26100(A)PC
# ...                              ...              ...          ...
# 2622              Aggravated Assault                F  245(A)(1)PC
# 2623             Weapon (carry/poss)                F  29800(A)1PC
# 2624                        Burglary                F        459PC
# 2625                   Vehicle Theft                F   10851(E)VC
# 2626                         Larceny                M      459.5PC
# 2627                         Robbery                F       A211PC
# 2628                        Burglary                F        459PC
# 2629              Aggravated Assault                F  245(A)(1)PC
# 2630              Aggravated Assault                F  245(A)(2)PC
# 2631       Moving Traffic Violations                F   20001(A)VC
# 2632  Miscellaneous Other Violations                F  594(A)(2)PC
# 2633              Aggravated Assault                F   417.6(A)PC
# 2634              Aggravated Assault                F   273.5(A)PC
# 2635                  Other Assaults                F     422(A)PC
# 2636             Forgery/Counterfeit                F    484E(D)PC
# 2637                  Other Assaults                F     422(A)PC
# 2658                   Vehicle Theft                F  487(D)(1)PC
# 4733                         Robbery                F        211PC
# 4734  Miscellaneous Other Violations                F       3056PC
# 4735         Receive Stolen Property                F     496(A)PC
# 4736              Aggravated Assault                F  245(A)(1)PC
# 4737                         Robbery                F        211PC
# 4738         Driving Under Influence                M   23152(A)VC
# 4739                         Larceny                F     487(A)PC
# 4740  Miscellaneous Other Violations                F  594(A)(2)PC
# 4743                  Other Assaults                F  243(C)(1)PC
# 4744              Aggravated Assault                F  245(A)(1)PC
# 4745                  Other Assaults                F  243(C)(2)PC
# 4746                  Other Assaults                F  243(C)(1)PC
# 4747  Miscellaneous Other Violations                F     594(A)PC
#
#                              Charge Description  \
# 156                   GET CREDIT/ETC OTHER'S ID
# 157   VEH MANSLAUGHTR/OPER VESSEL DUI & DUR FEL
# 158         TRANSPORT/SELL CONTROLLED SUBSTANCE
# 159       CARRYING CONCEALED WEAPON UPON PERSON
# 160    POSS F/ARM BY CONVICTED FELON/ADDICT/ETC
# 161    POSS F/ARM BY CONVICTED FELON/ADDICT/ETC
# 162           CARRY CONCEALED WEAPON IN VEHICLE
# 165                      TERRORIZE CAUSING FEAR
# 166        VANDALISM W/LOSS VALUED EQ OR > $400
# 167            TAKE VEHICLE W/O OWNER'S CONSENT
# 172            TAKE VEHICLE W/O OWNER'S CONSENT
# 173            TAKE VEHICLE W/O OWNER'S CONSENT
# 174                     ADW, NOT FIREARM, W/GBI
# 175            TAKE VEHICLE W/O OWNER'S CONSENT
# 176            TAKE VEHICLE W/O OWNER'S CONSENT
# 177                   TAKE VEH:NO CNSNT:SPEC PR
# 178            TAKE VEHICLE W/O OWNER'S CONSENT
# 179                      TERRORIZE CAUSING FEAR
# 180   CARRY LOADED F/ARM PRSON/HEH PUBLIC PLACE
# 181                             DEFACE PROPERTY
# 182                     ADW, NOT FIREARM, W/GBI
# 183                  DUI ALCOHOL CAUSING INJURY
# 184                                     ROBBERY
# 185                                    BURGLARY
# 186   BATTERY ON PO/EMERGENCY PERSONNEL W/O INJ
# 187                             DAMAGE PROPERTY
# 188      DISOBEY DOMESTIC RELATIONS COURT ORDER
# 189           CARRY CONCEALED WEAPON IN VEHICLE
# 190    POSS F/ARM BY CONVICTED FELON/ADDICT/ETC
# 191    PERMIT ANOTHER BRING LOADED F/ARM IN VEH
# ...                                         ...
# 2622                    ADW, NOT FIREARM, W/GBI
# 2623   POSS F/ARM BY CONVICTED FELON/ADDICT/ETC
# 2624                                   BURGLARY
# 2625                  TAKE VEH:NO CNSNT:SPEC PR
# 2626                                SHOPLIFTING
# 2627                          ATTEMPT - ROBBERY
# 2628                                   BURGLARY
# 2629                    ADW, NOT FIREARM, W/GBI
# 2630                              ADW W/FIREARM
# 2631           HIT AND RUN CAUSING INJURY/DEATH
# 2632                            DAMAGE PROPERTY
# 2633                 EXHIBIT/DRAW FIREARM W/GBI
# 2634   CORPORAL INJURY ON SPOUSE/COHABITANT/ETC
# 2635                     TERRORIZE CAUSING FEAR
# 2636   ACQUIRE ACCESS CARD IN 4+ NAMES > 12 MOS
# 2637                     TERRORIZE CAUSING FEAR
# 2658                 GRAND THEFT AUTO/HORSE/ETC
# 4733                                    ROBBERY
# 4734                 VIOLATION OF PAROLE:FELONY
# 4735      RECEIVING KNOWN STOLEN PROPERTY >$950
# 4736                    ADW, NOT FIREARM, W/GBI
# 4737                                    ROBBERY
# 4738                DRUNK DRIVING ALCOHOL/DRUGS
# 4739          GRAND THEFT MONEY/PROPERTY > $400
# 4740                            DAMAGE PROPERTY
# 4743  BATTERY ON CUSTODIAL OFFICER/FIREFIGHTER/
# 4744                    ADW, NOT FIREARM, W/GBI
# 4745                   BATTERY ON PEACE OFFICER
# 4746  BATTERY ON CUSTODIAL OFFICER/FIREFIGHTER/
# 4747                                  VANDALISM
#
#                                        Address  \
# 156                                 ST ANDREWS
# 157                                    OLYMPIC
# 158    1600 W  36TH                         PL
# 159    1200 E  50TH                         ST
# 160   10700 S  MAIN                         ST
# 161   10600 S  MAIN                         ST
# 162            109TH                        ST
# 165    3100 W  71ST                         ST
# 166                                       23RD
# 167                                     SPRING
# 172            SPRING                       ST
# 173            8TH                          ST
# 174                                       VINE
# 175                                     HOOVER
# 176            7TH                          ST
# 177            4TH                          ST
# 178            11TH                         ST
# 179    1100 W  47TH                         ST
# 180                                       45TH
# 181            4TH                          ST
# 182                                       51ST
# 183                                SAN VICENTE
# 184    3400 W  3RD                          ST
# 185            6TH                          ST
# 186            PICO                         BL
# 187                                        4TH
# 188    2800    LEEWARD                      AV
# 189                                     AVALON
# 190                                    MELROSE
# 191            MELROSE                      AV
# ...                                        ...
# 2622   2100 W  28TH                         ST
# 2623   8500    CRANFORD                     AV
# 2624           22ND                         ST
# 2625    800 S  NORMANDIE                    AV
# 2626    600 S  VIRGIL                       AV
# 2627  26000    FRAMPTON                     AV
# 2628   1200 W  6TH                          ST
# 2629  10200 S  MAIN                         ST
# 2630   1400 W  6TH                          ST
# 2631                                  FIGUEROA
# 2632           3RD                          ST
# 2633           6TH                          ST
# 2634  11800    REDBANK                      ST
# 2635   7500    AVALON                       BL
# 2636           88TH                         ST
# 2637                                   BUDLONG
# 2658           AVALON                       BL
# 4733    200 E  28TH                         ST
# 4734                                  CAHUENGA
# 4735                                  CAHUENGA
# 4736  12100    HART                         ST
# 4737   2400    CRENSHAW                     BL
# 4738   8000    LOUISE                       AV
# 4739           PICO                         BL
# 4740                                 HOLLYWOOD
# 4743   3900    COCO                         AV
# 4744                                 CHESPEALE
# 4745   6500    VICTORIA                     AV
# 4746   6500 S  VICTORIA                     AV
# 4747   9000    VANALDEN                     AV
#
#                          Cross Street              Location
# 156                          FOUNTAIN  (34.0949, -118.3109)
# 157                          MASSELIN  (34.0574, -118.3547)
# 158                               NaN  (34.0219, -118.3061)
# 159                               NaN   (33.998, -118.2543)
# 160                               NaN  (33.9392, -118.2739)
# 161                               NaN  (33.9402, -118.2739)
# 162                             GRAND  (33.9374, -118.2805)
# 165                               NaN  (33.9757, -118.3265)
# 166                           TRINITY  (34.0289, -118.2686)
# 167                               5TH   (34.0416, -118.244)
# 172                               6TH   (34.046, -118.2509)
# 173                       LOS ANGELES  (34.0413, -118.2517)
# 174                         HOLLYWOOD  (34.1007, -118.3494)
# 175                            VERNON  (34.0027, -118.2871)
# 176                           ALAMEDA   (34.035, -118.2386)
# 177                             TOWNE  (34.0444, -118.2407)
# 178   HILL                         ST  (34.0402, -118.2598)
# 179                               NaN  (34.0006, -118.2937)
# 180                           STANTON   (34.0096, -118.244)
# 181                          BROADWAY  (34.0495, -118.2494)
# 182                          FIGUEROA  (33.9965, -118.2827)
# 183                        BARRINGTON  (34.0536, -118.4655)
# 184                               NaN  (34.0728, -118.2878)
# 185   WALL                         ST  (34.0435, -118.2471)
# 186   BERENDO                      ST  (34.0473, -118.2936)
# 187                            SHATTO   (34.067, -118.2899)
# 188                               NaN  (34.0588, -118.2842)
# 189   51ST                         ST  (33.9966, -118.2652)
# 190                          HIGHLAND  (34.0835, -118.3386)
# 191   HIGHLAND                     AV  (34.0835, -118.3386)
# ...                               ...                   ...
# 2622                              NaN     (34.03, -118.312)
# 2623                              NaN   (34.2253, -118.401)
# 2624                            MINER  (33.7753, -118.2456)
# 2625                              NaN   (34.0561, -118.302)
# 2626                              NaN   (34.0637, -118.287)
# 2627                              NaN  (33.7866, -118.3044)
# 2628                              NaN  (34.0579, -118.2649)
# 2629                              NaN  (33.9438, -118.2739)
# 2630                              NaN  (34.0562, -118.2673)
# 2631                        ROSECRANS  (33.9019, -118.2827)
# 2632  RAMPART                      BL  (34.0667, -118.2797)
# 2633  BEAUDRY                      AV  (34.0529, -118.2596)
# 2634                              NaN  (34.2252, -118.3951)
# 2635                              NaN  (33.9722, -118.2652)
# 2636  MAIN                         ST  (33.9572, -118.2739)
# 2637                           VERNON  (34.0037, -118.2959)
# 2658  IMPERIAL                     HY  (33.9311, -118.2652)
# 4733                              NaN  (34.0228, -118.2686)
# 4734                            SELMA  (34.0998, -118.3295)
# 4735                            SELMA  (34.0998, -118.3295)
# 4736                              NaN  (34.1976, -118.3965)
# 4737                              NaN   (34.0338, -118.337)
# 4738                              NaN  (34.2157, -118.5099)
# 4739  PROSSER                      ST  (34.0524, -118.4248)
# 4740                         HIGHLAND  (34.1016, -118.3387)
# 4743                              NaN  (34.0155, -118.3497)
# 4744                            RODEO  (34.0171, -118.3531)
# 4745                              NaN  (33.9806, -118.3323)
# 4746                              NaN  (33.9806, -118.3323)
# 4747                              NaN  (34.2341, -118.5493)
#
# [100 rows x 17 columns]

# %%
'Pre-Delinquency' in emil_2018['Charge Group Description']
# Out:
# False

# %%
"Non-Criminal Detention" in emil_2018['Charge Group Description']
# Out:
# False

# %%
import re

regex = re.compile(r"\s([A-Z]....)\s")

booleans = []

for result in emil_2018['Charge Group Description']:
    
    if not re.search('\s([A-Z]....)\s', result):
        
        booleans.append(True)
        
    else:
        
        booleans.append(False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-b259338c33c5> in <module>
#       7 for result in emil_2018['Charge Group Description']:
#       8
# ----> 9     if not re.search('\s([A-Z]....)\s', result):
#      10
#      11         booleans.append(True)
#
# ~\Anaconda3\lib\re.py in search(pattern, string, flags)
#     181     """Scan through string looking for a match to the pattern, returning
#     182     a Match object, or None if no match was found."""
# --> 183     return _compile(pattern, flags).search(string)
#     184
#     185 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object
